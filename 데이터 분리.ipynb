# %%
import pandas as pd # 판다스 라이브러리
import csv # csv 라이브러리

# %%
tr = pd.read_csv("student.csv", encoding = 'utf-8')
tr.head()
# Out:
#    school  sex  age  address  famsize  Pstatus  Medu  Fedu  traveltime  \
# 0       1    1   18        1        0        0     4     4           2
# 1       1    1   17        1        0        1     1     1           1
# 2       1    1   15        1        1        1     1     1           1
# 3       1    1   15        1        0        1     4     2           1
# 4       1    1   16        1        0        1     3     3           1
#
#    studytime  ...  freetime  goout  Dalc  Walc  health  absences  G1  G2  G3  \
# 0          2  ...         3      4     1     1       3         6   5   6   6
# 1          2  ...         3      3     1     1       3         4   5   5   6
# 2          2  ...         3      2     2     3       3        10   7   8  10
# 3          3  ...         2      2     1     1       5         2  15  14  15
# 4          2  ...         3      2     1     2       5         4   6  10  10
#
#    pass
# 0     0
# 1     0
# 2     1
# 3     1
# 4     1
#
# ...

# %%
student_x_data = tr.loc[:, ['sex','age','activities','health','famsup','paid','higher','internet','Medu','Fedu','studytime','schoolsup','goout','G1','G2','G3']]
student_y_data = tr.loc[:,['pass']]

student_x_data.head()
# Out:
#    sex  age  activities  health  famsup  paid  higher  internet  Medu  Fedu  \
# 0    1   18           0       3       0     0       1         0     4     4
# 1    1   17           0       3       1     0       1         1     1     1
# 2    1   15           0       3       0     1       1         1     1     1
# 3    1   15           1       5       1     1       1         1     4     2
# 4    1   16           0       5       1     1       1         0     3     3
#
#    studytime  schoolsup  goout  G1  G2  G3
# 0          2          1      4   5   6   6
# 1          2          0      3   5   5   6
# 2          2          1      2   7   8  10
# 3          3          0      2  15  14  15
# 4          2          0      2   6  10  10

# %%
# Out:
#    pass
# 0     0
# 1     0
# 2     1
# 3     1
# 4     1
